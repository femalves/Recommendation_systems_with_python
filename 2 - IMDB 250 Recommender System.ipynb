# %%
import pandas as pd
import numpy as np

# Load the dataset into pandas df
df = pd.read_csv('data/movies_metadata.csv', low_memory=False)

df.head(15)
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13  False                                                NaN  44000000
# 14  False                                                NaN  98000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                      [{'id': 35, 'name': 'Comedy'}]
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                         homepage     id    imdb_id  \
# 0           http://toystory.disney.com/toy-story    862  tt0114709
# 1                                            NaN   8844  tt0113497
# 2                                            NaN  15602  tt0113228
# 3                                            NaN  31357  tt0114885
# 4                                            NaN  11862  tt0113041
# 5                                            NaN    949  tt0113277
# 6                                            NaN  11860  tt0114319
# 7                                            NaN  45325  tt0112302
# 8                                            NaN   9091  tt0114576
# 9   http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# 10                                           NaN   9087  tt0112346
# 11                                           NaN  12110  tt0112896
# 12                                           NaN  21032  tt0112453
# 13                                           NaN  10858  tt0113987
# 14                                           NaN   1408  tt0112760
#
#    original_language               original_title  \
# 0                 en                    Toy Story
# 1                 en                      Jumanji
# 2                 en             Grumpier Old Men
# 3                 en            Waiting to Exhale
# 4                 en  Father of the Bride Part II
# 5                 en                         Heat
# 6                 en                      Sabrina
# 7                 en                 Tom and Huck
# 8                 en                 Sudden Death
# 9                 en                    GoldenEye
# 10                en       The American President
# 11                en  Dracula: Dead and Loving It
# 12                en                        Balto
# 13                en                        Nixon
# 14                en             Cutthroat Island
#
#                                              overview    ...     release_date  \
# 0   Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1   When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2   A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3   Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4   Just when George Banks has recovered from his ...    ...       1995-02-10
# 5   Obsessive master thief, Neil McCauley leads a ...    ...       1995-12-15
# 6   An ugly duckling having undergone a remarkable...    ...       1995-12-15
# 7   A mischievous young boy, Tom Sawyer, witnesses...    ...       1995-12-22
# 8   International action superstar Jean Claude Van...    ...       1995-12-22
# 9   James Bond must unmask the mysterious head of ...    ...       1995-11-16
# 10  Widowed U.S. president Andrew Shepherd, one of...    ...       1995-11-17
# 11  When a lawyer shows up at the vampire's doorst...    ...       1995-12-22
# 12  An outcast half-wolf risks his life to prevent...    ...       1995-12-22
# 13  An all-star cast powers this epic look at Amer...    ...       1995-12-22
# 14  Morgan Adams and her slave, William Shaw, are ...    ...       1995-12-22
#
#         revenue runtime                                   spoken_languages  \
# 0   373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1   262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3    81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4    76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5   187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6           0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7           0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8    64350171.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9   352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10  107879496.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11          0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 12   11348324.0    78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13   13681765.0   192.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14   10017322.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#       status                                            tagline  \
# 0   Released                                                NaN
# 1   Released          Roll the dice and unleash the excitement!
# 2   Released  Still Yelling. Still Fighting. Still Ready for...
# 3   Released  Friends are the people who let you be yourself...
# 4   Released  Just When His World Is Back To Normal... He's ...
# 5   Released                           A Los Angeles Crime Saga
# 6   Released  You are cordially invited to the most surprisi...
# 7   Released                             The Original Bad Boys.
# 8   Released                         Terror goes into overtime.
# 9   Released               No limits. No fears. No substitutes.
# 10  Released  Why can't the most powerful man in the world h...
# 11  Released                                                NaN
# 12  Released                     Part Dog. Part Wolf. All Hero.
# 13  Released  Triumphant in Victory, Bitter in Defeat. He Ch...
# 14  Released  The Course Has Been Set. There Is No Turning B...
#
#                           title  video vote_average vote_count
# 0                     Toy Story  False          7.7     5415.0
# 1                       Jumanji  False          6.9     2413.0
# 2              Grumpier Old Men  False          6.5       92.0
# 3             Waiting to Exhale  False          6.1       34.0
# 4   Father of the Bride Part II  False          5.7      173.0
# 5                          Heat  False          7.7     1886.0
# 6                       Sabrina  False          6.2      141.0
# 7                  Tom and Huck  False          5.4       45.0
# 8                  Sudden Death  False          5.5      174.0
# 9                     GoldenEye  False          6.6     1194.0
# 10       The American President  False          6.5      199.0
# 11  Dracula: Dead and Loving It  False          5.7      210.0
# 12                        Balto  False          7.1      423.0
# 13                        Nixon  False          7.1       72.0
# 14             Cutthroat Island  False          5.7      137.0
#
# [15 rows x 24 columns]

# %% [markdown]
# ## Classifying movies by rating acording to IMDB Weighted Rating (WR)
#
# WR = (v/ (v+m) * R) + ( m / (v+m) * C)
#
#
# - v is the number of votes garnered by the movie
# - m is the minimum number of votes required for the movie to be in the chart.
# - R is the mean rating of the movie
# - C is the mean rating of all the movies in the dataset

# %% [markdown]
# For our recommender, we will use the number of votes garnered by the 80th percentile movie as our value for m. In other words, for a movie to be considered in the rankings, it must have garnered move votes than at least 80% of the movies peresent in our dataset.

# %%
# Calculate the number of votes garnered by the 80th percentile movie
m = df['vote_count'].quantile(0.80)

# %%
m
# Out:
# 50.0

# %%
# Only consider movies that have runtime greater than 45 minutes and less than 300 minutes. 
q_movies = df[(df['runtime'] >= 45) & (df['runtime'] <= 300)]

# %%
# Only consider movies that have garnered more than m votes
q_movies = q_movies[q_movies['vote_count'] >= m]

# %%
q_movies.shape
# Out:
# (8963, 24)

# %%
# Calculate C, the mean rating for all the movies in the dataset
C = df['vote_average'].mean()
C
# Out:
# 5.618207215133889

# %%
# Function to compute the IMDB weighted rating for each movie
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/ (v+m) * R) + ( m / (v+m) * C)

# %%
# Computer the score using the weighted_rating function defined above
q_movies['score'] =  q_movies.apply(weighted_rating, axis=1)

# %%
q_movies[['title', 'release_date', 'vote_count', 'score']].sort_values('score', ascending=False).head(100)
# Out:
#                                                title release_date  vote_count  \
# 10309                    Dilwale Dulhania Le Jayenge   1995-10-20       661.0
# 314                         The Shawshank Redemption   1994-09-23      8358.0
# 834                                    The Godfather   1972-03-14      6024.0
# 40251                                     Your Name.   2016-08-26      1030.0
# 12481                                The Dark Knight   2008-07-16     12269.0
# 2843                                      Fight Club   1999-10-15      9678.0
# 292                                     Pulp Fiction   1994-09-10      8670.0
# 522                                 Schindler's List   1993-11-29      4436.0
# 23673                                       Whiplash   2014-10-10      4376.0
# 5481                                   Spirited Away   2001-07-20      3968.0
# 2211                               Life Is Beautiful   1997-12-20      3643.0
# 1178                          The Godfather: Part II   1974-12-20      3418.0
# 1152                 One Flew Over the Cuckoo's Nest   1975-11-18      3001.0
# 1176                                          Psycho   1960-06-16      2405.0
# 351                                     Forrest Gump   1994-07-06      8147.0
# 1184                     Once Upon a Time in America   1984-02-16      1104.0
# 1154                         The Empire Strikes Back   1980-05-17      5998.0
# 18465                               The Intouchables   2011-11-02      5410.0
# 289                           Leon: The Professional   1994-09-14      4293.0
# 3030                                  The Green Mile   1999-12-10      4166.0
# 1170                                      GoodFellas   1990-09-12      3211.0
# 2216                              American History X   1998-10-30      3120.0
# 1161                                    12 Angry Men   1957-03-25      2130.0
# 9698                            Howl's Moving Castle   2004-11-19      2049.0
# 2884                               Princess Mononoke   1997-07-12      2041.0
# 5878                                     City of God   2002-02-05      1852.0
# 877                                      Rear Window   1954-08-01      1531.0
# 15480                                      Inception   2010-07-14     14075.0
# 22879                                   Interstellar   2014-11-05     11187.0
# 7000   The Lord of the Rings: The Return of the King   2003-12-01      8226.0
# ...                                              ...          ...         ...
# 23753                        Guardians of the Galaxy   2014-07-30     10014.0
# 2458                                      The Matrix   1999-03-30      9079.0
# 22131                        The Wolf of Wall Street   2013-12-25      6768.0
# 30315                                     Inside Out   2015-06-09      6737.0
# 13605                           Inglourious Basterds   2009-08-18      6598.0
# 17437   Harry Potter and the Deathly Hallows: Part 2   2011-07-07      6141.0
# 23675                                      Gone Girl   2014-10-01      6023.0
# 3456                                       Gladiator   2000-05-01      5566.0
# 1919                             Saving Private Ryan   1998-07-24      5148.0
# 1167                              Return of the Jedi   1983-05-23      4763.0
# 40882                                     La La Land   2016-11-29      4745.0
# 1171                                           Alien   1979-05-25      4564.0
# 11316                                   The Departed   2006-10-05      4455.0
# 882                                    The Apartment   1960-06-15       498.0
# 22168                                            Her   2013-12-18      4215.0
# 536                                     Blade Runner   1982-06-25      3833.0
# 21878                               12 Years a Slave   2013-10-18      3787.0
# 7208           Eternal Sunshine of the Spotless Mind   2004-03-19      3758.0
# 2742                                 American Beauty   1999-09-15      3438.0
# 883                                 Some Like It Hot   1959-03-18       835.0
# 21604                                      Prisoners   2013-09-18      3183.0
# 897                            2001: A Space Odyssey   1968-04-10      3075.0
# 21948                             Dallas Buyers Club   2013-09-07      2973.0
# 1624                               Good Will Hunting   1997-12-05      2880.0
# 1179                               Full Metal Jacket   1987-06-26      2595.0
# 3824                             Requiem for a Dream   2000-10-27      2525.0
# 38718                                 The Handmaiden   2016-06-01       453.0
# 17603                                       The Help   2011-08-09      1966.0
# 25044                                Song of the Sea   2014-09-06       420.0
# 37863                                    Sing Street   2016-03-11       669.0
#
#           score
# 10309  8.855148
# 314    8.482863
# 834    8.476278
# 40251  8.366584
# 12481  8.289115
# 2843   8.286216
# 292    8.284623
# 522    8.270109
# 23673  8.269704
# 5481   8.266628
# 2211   8.263691
# 1178   8.261335
# 1152   8.256051
# 1176   8.245381
# 351    8.184252
# 1184   8.183804
# 1154   8.178656
# 18465  8.176357
# 289    8.170276
# 3030   8.169381
# 1170   8.160414
# 2216   8.159278
# 1161   8.140785
# 9698   8.138499
# 2884   8.138264
# 5878   8.132130
# 877    8.118349
# 15480  8.091215
# 22879  8.088957
# 7000   8.085006
# ...         ...
# 23753  7.888664
# 2458   7.887503
# 22131  7.883266
# 30315  7.883190
# 13605  7.882839
# 17437  7.881572
# 23675  7.881214
# 3456   7.879685
# 1919   7.878051
# 1167   7.876296
# 40882  7.876207
# 1171   7.875273
# 11316  7.874675
# 882    7.873559
# 22168  7.873250
# 536    7.870618
# 21878  7.870266
# 7208   7.870039
# 2742   7.867291
# 883    7.865435
# 21604  7.864711
# 897    7.863491
# 21948  7.862259
# 1624   7.861062
# 1179   7.856866
# 3824   7.855693
# 38718  7.853301
# 17603  7.843408
# 25044  7.835979
# 37863  7.834368
#
# [100 rows x 4 columns]

# %%
df = q_movies[['title', 'genres', 'release_date', 'runtime', 'vote_average', 'vote_count']]

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 4  Father of the Bride Part II
# 5                         Heat
#
#                                               genres release_date  runtime  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   1995-10-30     81.0
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   1995-12-15    104.0
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   1995-12-22    101.0
# 4                     [{'id': 35, 'name': 'Comedy'}]   1995-02-10    106.0
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   1995-12-15    170.0
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 4           5.7       173.0
# 5           7.7      1886.0

# %%
# Convert release_date into pandas datetime format
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# Extract year from the datetime
df['year'] = df['release_date'].apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# Helper function to convert NAT to 0 and all other years to integers
def convert_int(x): 
    try: 
        return int(x)
    except: 
        return 0

# %%
# Apply convert_int to the year feature
df['year'] = df['year'].apply(convert_int)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Drop the release_date column
df = df.drop('release_date', axis=1)

# Display the dataframe
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 4  Father of the Bride Part II
# 5                         Heat
#
#                                               genres  runtime  vote_average  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     81.0           7.7
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    104.0           6.9
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...    101.0           6.5
# 4                     [{'id': 35, 'name': 'Comedy'}]    106.0           5.7
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    170.0           7.7
#
#    vote_count  year
# 0      5415.0  1995
# 1      2413.0  1995
# 2        92.0  1995
# 4       173.0  1995
# 5      1886.0  1995

# %%
# Print genres of the first movie
df.iloc[0]['genres']
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
# Destringify genres dictionary

# Import the literal_eval funtion from ast 
from ast import literal_eval

# Apply a stringified list and output its type
a = "[1,2,3]"
print(type(a))

# Define a stringified list and output type
b = literal_eval(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'list'>

# %%
# Convert all NaN stringified empty lists
df['genres'] = df['genres'].fillna('[]')

# %%
# Apply literal_eval to convert to the list object
df['genres'] = df['genres'].apply(literal_eval)

# %%
#Convert list of dictionaries to a list of strings
df['genres'] = df['genres'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df.head()
# Out:
#                          title                            genres  runtime  \
# 0                    Toy Story       [Animation, Comedy, Family]     81.0
# 1                      Jumanji      [Adventure, Fantasy, Family]    104.0
# 2             Grumpier Old Men                 [Romance, Comedy]    101.0
# 4  Father of the Bride Part II                          [Comedy]    106.0
# 5                         Heat  [Action, Crime, Drama, Thriller]    170.0
#
#    vote_average  vote_count  year
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 4           5.7       173.0  1995
# 5           7.7      1886.0  1995

# %%
# Create title row for each of the genres
s = df.apply(lambda x: pd.Series(x['genres']), axis=1).stack().reset_index(level=1, drop=True)

# %%
# Name the new feature as 'genre'
s.name = 'genre'

# Create a new dataframe gen_df which by dropping th eold 'genres' feature an adding the new 'genre'
gen_df = df.drop('genres', axis=1).join(s)

# Print the head of the new gen_df
gen_df.head()
# Out:
#        title  runtime  vote_average  vote_count  year      genre
# 0  Toy Story     81.0           7.7      5415.0  1995  Animation
# 0  Toy Story     81.0           7.7      5415.0  1995     Comedy
# 0  Toy Story     81.0           7.7      5415.0  1995     Family
# 1    Jumanji    104.0           6.9      2413.0  1995  Adventure
# 1    Jumanji    104.0           6.9      2413.0  1995    Fantasy

# %%
def build_chart(gen_df, percentile=0.8): 
    #Ask for preferred genres
    print("Input preferred genre")
    genre = input()
    
    #Ask for lower limit of duration
    print("Input shortest duration")
    low_time = int(input())
    
    #Ask for upper limit of duration
    print("Input longest duration")
    high_time = int(input())
    
    #Ask for lower limit of timeline
    print("Input earliest year")
    low_year = int(input())
    
    #Ask for upper limit of timeline
    print("Input latest year")
    high_year = int(input())
    
    #Define a new movies variable to store the preferred movies. Copy the contents of gen_df to movies
    movies = gen_df.copy()
    
    #Filter based on the condition
    movies = movies[(movies['genre'] == genre) & 
                    (movies['runtime'] >= low_time) & 
                    (movies['runtime'] <= high_time) & 
                    (movies['year'] >= low_year) & 
                    (movies['year'] <= high_year)]
    
    #Compute the values of C and m for the filtered movies
    C = movies['vote_average'].mean()
    m = movies['vote_count'].quantile(percentile)
    
    #Only consider movies that have higher than m votes. Save this in a new dataframe q_movies
    q_movies = movies.copy().loc[movies['vote_count'] >= m]
    
    #Calculate score using the IMDB formula
    q_movies['score'] = q_movies.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) 
                                       + (m/(m+x['vote_count']) * C)
                                       ,axis=1)

    #Sort movies in descending order of their scores
    q_movies = q_movies.sort_values('score', ascending=False)
    
    return q_movies

# %%
build_chart(gen_df).head()
# Out:
# Input preferred genre
# Animation
# Input shortest duration
# 30
# Input longest duration
# 120
# Input earliest year
# 1993
# Input latest year
# 2010
#                       title  runtime  vote_average  vote_count  year  \
# 359           The Lion King     89.0           8.0      5520.0  1994
# 9698   Howl's Moving Castle    119.0           8.2      2049.0  2004
# 13724                    Up     96.0           7.8      7048.0  2009
# 12704                WALL·E     98.0           7.8      6439.0  2008
# 0                 Toy Story     81.0           7.7      5415.0  1995
#
#            genre     score
# 359    Animation  7.780574
# 9698   Animation  7.662559
# 13724  Animation  7.645951
# 12704  Animation  7.633224
# 0      Animation  7.521005

# %%
# Convert the cleaned (non-exploded) dataframe df into a CSV file and save it in the data folder
# Set parameter index to False as the index of the DataFrame has no inherent meaning 

df.to_csv('data/metadata_clean.csv', index=False)
